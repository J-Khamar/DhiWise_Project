# %%
# Upgrade pip package manager
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (23.2.1)

# %%
# This command installs various Python packages and their specific versions necessary for the project.
# These packages include utilities for working with machine learning models, data handling, and other dependencies.
# !pip install \
    pyyaml \
    gin \
    scipy \
    pycocotools \
    pandas \
    lxml \
    lvis \
    matplotlib \
    contextlib2 \
    avro-python3 \
    opencv-python \
    tensorflow-io \
    pyparsing==2.4.7 \
    tensorflow==2.13.0
# Out:
# Requirement already satisfied: pyyaml in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (6.0.1)
# Collecting gin
#   Using cached gin-0.1.006.tar.bz2 (3.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (1.11.3)
# Collecting pycocotools
#   Obtaining dependency information for pycocotools from https://files.pythonhosted.org/packages/bb/86/480aff3c16abf2cdc63c708b3e02ca4dee1d47de114996c6c3446c67b808/pycocotools-2.0.7-cp39-cp39-macosx_10_9_universal2.whl.metadata
#   Using cached pycocotools-2.0.7-cp39-cp39-macosx_10_9_universal2.whl.metadata (1.1 kB)
# Requirement already satisfied: pandas in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (2.1.1)
# Requirement already satisfied: lxml in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (4.9.3)
# Collecting lvis
#   Using cached lvis-0.5.3-py3-none-any.whl (14 kB)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/95/25/4178ff92b6e523c9ad48ed3822b26375d5a5173b28b75ac7c1cb640a9c94/matplotlib-3.8.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Using cached matplotlib-3.8.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting contextlib2
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting avro-python3
#   Using cached avro-python3-1.10.2.tar.gz (38 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: opencv-python in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (4.8.0.76)
# Collecting tensorflow-io
#   Obtaining dependency information for tensorflow-io from https://files.pythonhosted.org/packages/ae/f9/fe666ecf721bf7a9b7f12ed4c6a05a5a7a73a040c1b5d8f82363612e4106/tensorflow_io-0.34.0-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Using cached tensorflow_io-0.34.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting pyparsing==2.4.7
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting tensorflow==2.13.0
#   Obtaining dependency information for tensorflow==2.13.0 from https://files.pythonhosted.org/packages/df/00/35b50648124596573d3ffb9c7441f8a6175b4c58317c4d9f5bcc1d52cc8d/tensorflow-2.13.0-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow-2.13.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (2.6 kB)
# Collecting tensorflow-macos==2.13.0 (from tensorflow==2.13.0)
#   Obtaining dependency information for tensorflow-macos==2.13.0 from https://files.pythonhosted.org/packages/c4/4d/8dcb9ddf53ad0070cccb50cbdaad29d1a226a253966d9a6b1de34bd61ec4/tensorflow_macos-2.13.0-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow_macos-2.13.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (3.2 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.1.21 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for flatbuffers>=23.1.21 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 227.9 kB/s eta 0:00:001m212.9 kB/s eta 0:00:01
# Collecting h5py>=2.9.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for h5py>=2.9.0 from https://files.pythonhosted.org/packages/e4/78/0a42a0c518b7a2cee32f9645ebf343b78390428c6889e4ef60af51fbbd3c/h5py-3.9.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading h5py-3.9.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/32/1f/981809b77b71972beec34b3ff5422c1b1f7e519daac7b3cbd055c05ba2cf/libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting numpy<=1.24.3,>=1.22 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading numpy-1.24.3-cp39-cp39-macosx_11_0_arm64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 125.6 kB/s eta 0:00:00m eta 0:00:010:00:04
# Collecting opt-einsum>=2.3.2 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 129.3 kB/s eta 0:00:001m124.3 kB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/88/12/efb5896c901382548ecb58d0449885a8f9aa62bb559d65e5a8a47f122629/protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Requirement already satisfied: setuptools in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting wrapt>=1.11.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading wrapt-1.15.0-cp39-cp39-macosx_11_0_arm64.whl (36 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for grpcio<2.0,>=1.24.3 from https://files.pythonhosted.org/packages/9c/9a/cd91c03b4e4cebb634f28ca89c2363b837d88e94b6fefce105d5ae885c57/grpcio-1.59.0-cp39-cp39-macosx_10_10_universal2.whl.metadata
#   Downloading grpcio-1.59.0-cp39-cp39-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 70.9 kB/s eta 0:00:00m eta 0:00:010:00:03m
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for tensorflow-estimator<2.14,>=2.13.0 from https://files.pythonhosted.org/packages/72/5c/c318268d96791c6222ad7df1651bbd1b2409139afeb6f468c0f327177016/tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for keras<2.14,>=2.13.1 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Downloading keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from pandas) (2023.3)
# Collecting cycler>=0.10.0 (from lvis)
#   Obtaining dependency information for cycler>=0.10.0 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting Cython>=0.29.12 (from lvis)
#   Obtaining dependency information for Cython>=0.29.12 from https://files.pythonhosted.org/packages/a5/70/11e973497f9f635654ef1fefffd0573f83813a65cd9221215f08192fb531/Cython-3.0.3-py2.py3-none-any.whl.metadata
#   Downloading Cython-3.0.3-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting kiwisolver>=1.1.0 (from lvis)
#   Obtaining dependency information for kiwisolver>=1.1.0 from https://files.pythonhosted.org/packages/89/a8/3b7e14121bea4438b87630557645bb7648b17b54acaa39b93f4bf7f8d33e/kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/09/fe/086e6847ee53da10ddf0b6c5e5f877ab43e68e355d2f4c85f67561ee8a57/contourpy-1.1.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading contourpy-1.1.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/cb/b1/f476072a37ded38f83aa220d74af10a3e18889dd6b2b775c6f5900cbe2e1/fonttools-4.43.1-cp39-cp39-macosx_10_9_universal2.whl.metadata
#   Downloading fonttools-4.43.1-cp39-cp39-macosx_10_9_universal2.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 76.6 kB/s eta 0:00:0031m75.3 kB/s eta 0:00:01
# Collecting pillow>=6.2.0 (from matplotlib)
#   Obtaining dependency information for pillow>=6.2.0 from https://files.pythonhosted.org/packages/3c/56/8449d670bae6e8f1b45e12cc2746561e42d3d80e3a432bf6f6e71c260aa1/Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Obtaining dependency information for importlib-resources>=3.2.0 from https://files.pythonhosted.org/packages/65/6e/09d8816b5cb7a4006ef8ad1717a2703ad9f331dae9717d9f22488a2d6469/importlib_resources-6.1.0-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting tensorflow-io-gcs-filesystem==0.34.0 (from tensorflow-io)
#   Obtaining dependency information for tensorflow-io-gcs-filesystem==0.34.0 from https://files.pythonhosted.org/packages/f9/17/74b5b4f7c965aa4e7cbf7dd287744b71692abc52d7c805b4b1d70175f64f/tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for wheel<1.0,>=0.23.0 from https://files.pythonhosted.org/packages/b8/8b/31273bf66016be6ad22bb7345c37ff350276cfd46e389a0c2ac5da9d9073/wheel-0.41.2-py3-none-any.whl.metadata
#   Using cached wheel-0.41.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/d7/88/1826b0c047c48763b36ed854a984127b430a16b70003155d7b19975f1d59/google_auth-2.23.2-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/bb/c1/50caaec6cadc1c6adc8fe351e03bd646d6e4dd17f55fca0f4c8d7ea8d3e9/Markdown-3.5-py3-none-any.whl.metadata
#   Downloading Markdown-3.5-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/b6/a5/54b01f663d60d5334f6c9c87c26274e94617a4fd463d812463626423b10d/werkzeug-3.0.0-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 151.0 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jeetkhamar/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.1.3)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 233.5 kB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 203.8 kB/s eta 0:00:001m198.0 kB/s eta 0:00:01
# Downloading tensorflow-2.13.0-cp39-cp39-macosx_12_0_arm64.whl (1.9 kB)
# Downloading tensorflow_macos-2.13.0-cp39-cp39-macosx_12_0_arm64.whl (189.3 MB)
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/189.3 MB 36.0 kB/s eta 1:21:53

# %%
# Install the 'wget' package using pip.
# !pip install wget

# Import the 'wget' module for downloading files.
import wget

# %%
# Check if the object detection module is already present. If not, clone the TensorFlow models repository.
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Define the URL for downloading the protoc compiler.
url = "https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"

# Download the protoc compiler.
wget.download(url)

# Move the downloaded file to the designated path for protoc.
# !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}

# Extract the protoc compiler in the designated path.
# !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip

# Add the path to the protoc compiler to the system's environment variable.
os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))

# Compile the protocol buffers for object detection.
# !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=.

# Copy the setup.py file from object_detection/packages/tf2 to the main directory.
# !cd Tensorflow/models/research && copy object_detection\\packages\\tf2\\setup.py setup.py

# Build and install the object detection package.
# !cd Tensorflow/models/research && python setup.py build && python setup.py install

# Install slim package.
# !cd Tensorflow/models/research/slim && pip install -e .

# %%
# Define the path to the verification script.
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')

# Run the verification script.
# !python {VERIFICATION_SCRIPT}

# %%
from constants import CUSTOM_MODEL_NAME, PRETRAINED_MODEL_NAME, PRETRAINED_MODEL_URL, TF_RECORD_SCRIPT_NAME, LABEL_MAP_NAME, paths, files

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-4')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'bottombar_17.png')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=3,
            min_score_thresh=.4,
            agnostic_mode=False)

plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()
